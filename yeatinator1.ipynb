# %% [markdown]
# # Yeatinator - Generate Lyrics in the STYLE of Your Favorite Artists
#
# ![Yeatinator Logo](./yeat.jpg)

# %%
from yeatinor import *

# %% [markdown]
# We can use Genius API to retrieve the lyrics from a various Yeat songs.

# %%
songs_yeat = get_songs_by_artist('Yeat',300)
# Out:
# Searching for songs by Yeat...
#
# Song 1: "Talk"
# Song 2: "Monëy so big"
# Song 3: "Dub"
# Song 4: "Rich Minion"
# Song 5: "Flawlëss"
# Song 6: "Gët Busy"
# Song 7: "Already Rich"
# Song 8: "Sorry Bout That"
# Song 9: "Poppin"
# Song 10: "Out thë way"
# Song 11: "Big tonka"
# Song 12: "Turban"
# Song 13: "If We Being Rëal"
# Song 14: "Breathe"
# Song 15: "On tha linë"
# Song 16: "Rollin"
# Song 17: "Split"
# Song 18: "How it go"
# Song 19: "Money Twërk"
# Song 20: "Still countin"
# Song 21: "Nun id change"
# Song 22: "No morë talk"
# Song 23: "MEh (Remix)"
# Song 24: "Bëttr 0ff"
# Song 25: "Doublë"
# Song 26: "​bigger thën everything"
# Song 27: "Rackz got më"
# Song 28: "Lying 4 fun"
# Song 29: "Ya Ya"
# Song 30: "Psycho CEO"
# Song 31: "Wat ü want"
# Song 32: "Power Trip"
# Song 33: "Trëndy way"
# Song 34: "U could tëll"
# Song 35: "Mysëlf"
# Song 36: "Mad bout that"
# Song 37: "ILUV"
# Song 38: "Tell më"
# Song 39: "X With The Boot Up"
# Song 40: "2093"
# Song 41: "Timë Passed"
# Song 42: "On Livë"
# Song 43: "3G"
# Song 44: "Not Tha Samë"
# Song 45: "Nothing Changë"
# Song 46: "Rëal six"
# Song 47: "U Should Know"
# Song 48: "Jus bëtter"
# Song 49: "Outsidë"
# Song 50: "Rav3 p4rty"
# Song 51: "Twizzy Rich"
# Song 52: "Shmunk"
# Song 53: "Nvr again"
# Song 54: "Off Tha Lot"
# Song 55: "As We Speak"
# Song 56: "X Still"
# Song 57: "Fukit"
# Song 58: "Tonka"
# Song 59: "Mr. Inbetweenit"
# Song 60: "Systëm"
# Song 61: "Woa...!"
# Song 62: "Type monëy"
# Song 63: "WAR 2"
# Song 64: "Bäk 2 BED"
# Song 65: "Goin Back 2 Ella"
# Song 66: "Now"
# Song 67: "Krank"
# Song 68: "Taliban"
# Song 69: "Sïck"
# Song 70: "Got rich"
# Song 71: "Up off X"
# Song 72: "Morë"
# Song 73: "Luh gëek"
# Song 74: "Run Thëy Mouth"
# Song 75: "Nëw turban"
# Song 76: "Bought The Earth"
# Song 77: "HeliMAn"
# Song 78: "Gëek high"
# Song 79: "Can’t stop it"
# Song 80: "Forëally / 4Ly"
# Song 81: "Wat it feel lykë"
# Song 82: "Shhhh"
# Song 83: "Rokstar"
# Song 84: "Stayëd tha same"
# Song 85: "Mëan feen"
# Song 86: "Tonka 2"
# Song 87: "Kant rëlax"
# Song 88: "Narcoticz"
# Song 89: "Familia"
# Song 90: "Told ya"
# Song 91: "Cmon"
# Song 92: "Slamm"
# Song 93: "All of it"
# Song 94: "Wtf thëy on"
# Song 95: "King tonka"
# Song 96: "1093"
# Song 97: "Hatër"
# Song 98: "7 nightz"
# Song 99: "Hëavyweight"
# Song 100: "Lët ya know"
# Song 101: "Aint Try (Tried Once)"
# Song 102: "Shade"
# Song 103: "Bad bënd / DëMON"
# Song 104: "Lyfë* / Lyfestyle*"
# Song 105: "Sum 2 do"
# Song 106: "Dëserve it"
# Song 107: "Diëd B4"
# Song 108: "Got it all"
# Song 109: "Rëady*"
# Song 110: "Swërved It"
# Song 111: "All daë"
# Song 112: "Smooktobër"
# Song 113: "Kant changë"
# Song 114: "X ta C"
# Song 115: "Kant dië"
# Song 116: "Back homë"
# Song 117: "Morning mudd"
# Song 118: "Way back"
# Song 119: "Watch"
# Song 120: "Call më"
# Song 121: "Up"
# Song 122: "WAR 1"
# Song 123: "Good Day"
# Song 124: "Back up"
# Song 125: "Team ceo"
# Song 126: "No commënt"
# Song 127: "Dëmon tied"
# Song 128: "Comë on"
# Song 129: "Tru to U"
# Song 130: "Talk 2 God"
# Song 131: "All typëz"
# Song 132: "H.A.B"
# Song 133: "SKLUB"
# Song 134: "Riot & Set it off"
# Song 135: "Rackie Fitness"
# Song 136: "Never quit"
# Song 137: "‎Nëw Phone"
# Song 138: "No fëelingz"
# Song 139: "Real trendsettër"
# Song 140: "Tëslas & Rovers"
# Song 141: "Jump"
# Song 142: "Keep Pushin"
# Song 143: "Luh m"
# Song 144: "Killin ëm"
# Song 145: "Factz"
# Song 146: "All I See"
# Song 147: "Holy 1"
# Song 148: "D I E"
# Song 149: "Bak on ëm"
# Song 150: "Psychocainë"
# Song 151: "Dnt lië"
# Song 152: "Oh eX whY"
# Song 153: "Trië 2 Tell U outro"
# Song 154: "Livë Hi"
# Song 155: "Perctivated"
# Song 156: "Big Stonëz"
# Song 157: "FATË (BONUS)"
# Song 158: "Real Is Rarë"
# Song 159: "Mountain Climbërs"
# Song 160: "Flip"
# Song 161: "Hëy"
# Song 162: "Died once"
# Song 163: "Lil Krazy"
# Song 164: "Swërved It (4L)"
# Song 165: "Twizzy"
# Song 166: "TURNMEUP"
# Song 167: "Always Alivë"
# Song 168: "Latë Night"
# Song 169: "Marching / Touchdown*"
# Song 170: "Liftëd"
# Song 171: "Aint Us"
# Song 172: "Callin më"
# Song 173: "Balënci Feet"
# Song 174: "Come Again"
# Song 175: "RolËy DÆ 2"
# Song 176: "Provë sum"
# Song 177: "Cali"
# Song 178: "I do wat i want*"
# Song 179: "Never Changëd"
# Song 180: "Krazyup"
# Song 181: "Bootup"
# Song 182: "Chanëlly"
# Song 183: "Trëndy"
# Song 184: "Jus Wokëup"
# Song 185: "​​Money Twërk 3"
# Song 186: "Im tha kind dëvil"
# Song 187: "Insidë out"
# Song 188: "1st Hunnid"
# Song 189: "My Turn"
# Song 190: "King Tonka (2022)"
# Song 191: "Geek party"
# Song 192: "Trënds & Topics*"
# Song 193: "FLYTROOP"
# Song 194: "Built Different"
# Song 195: "Overloaded"
# Song 196: "Watch Dis"
# Song 197: "Stay Up"
# Song 198: "Nutrition in Switzerland"
# Song 199: "Tell u again (Urus SKLUB)*"
# Song 200: "Oh My Pockëts"
# Song 201: "Bëd Side"
# Song 202: "Last day (Snippet)"
# Song 203: "Flashëy"
# Song 204: "Wonky"
# Song 205: "Havin motion"
# Song 206: "Luh Gëeky"
# Song 207: "​WTF"
# Song 208: "Dëmon"
# Song 209: "Fyed Up"
# Song 210: "Poppin (OG)"
# Song 211: "Ok Kool"
# Song 212: "Big Trunk"
# Song 213: "Serious (Siri)*"
# Song 214: "Sidëwayz"
# Song 215: "Free em"
# Song 216: "Sleeptalking"
# Song 217: "Wanna be më*"
# Song 218: "Last Day"
# Song 219: "2x2"
# Song 220: "GEEK TIMË"
# Song 221: "​​wat happën"
# Song 222: "Goin’ Crazy"
# Song 223: "Supër Test"
# Song 224: "IDGAF (Demo)"
# Song 225: "Cayenne outside"
# Song 226: "Long Money"
# Song 227: "X"
# Song 228: "Haha"
# Song 229: "Number 1"
# Song 230: "Real Spill"
# Song 231: "2 Turnty (Extortion)"
# Song 232: "Live dis lyfë"
# Song 233: "I got / evëry spot*"
# Song 234: "Bizzy"
# Song 235: "Wavëy Krazy"
# Song 236: "Go away"
# Song 237: "Every Typa Bad (Damage)"
# Song 238: "Wild West"
# Song 239: "Project lyfestyle"
# Song 240: "Finally #FRËË"
# Song 241: "Aint worried"
# Song 242: "WTW"
# Song 243: "Money Twërk 2"
# Song 244: "Swërve"
# Song 245: "W.A.H.W.G.C"
# Song 246: "Hëllcat"
# Song 247: "Money Fetish"
# Song 248: "Tha Worstie"
# Song 249: "2 Up"
# Song 250: "Feel it"
# Song 251: "Feel more"
# Song 252: "YEA YEA"
# Song 253: "Every Sunday"
# Song 254: "Crashëd tha jet"
# Song 255: "Watchu Said?"
# Song 256: "Duckcontëst"
# Song 257: "All 4 Nothin"
# Song 258: "Just know*"
# Song 259: "Cöming Down"
# Song 260: "Fax*"
# Song 261: "Playin Games (Dirtball Rich)*"
# Song 262: "Money N Drugs"
# Song 263: "EVERYTIME"
# Song 264: "1st Off ...."
# Song 265: "D I E (Duplicate)"
# Song 266: "Would ya v2"
# Song 267: "Stood Taller"
# Song 268: "ILLUMINATE"
# Song 269: "Timë Out"
# Song 270: "2day"
# Song 271: "Talk Money"
# Song 272: "​​​​died before"
# Song 273: "Lyfëborg (Wolf)"
# Song 274: "Breakfast"
# Song 275: "Not worried"
# Song 276: "Get Up"
# Song 277: "King tonka universë*"
# Song 278: "I’m up / Wassup matë*"
# Song 279: "Let’s be honëst*"
# Song 280: "New X"
# Song 281: "Skufflr (Rushmore)*"
# Song 282: "GO2WORK"
# Song 283: "Nobu"
# Song 284: "Can’t Think"
# Song 285: "Dirty X"
# Song 286: "Hard 2 miss"
# Song 287: "Shakëy (Pull Up On Meh)"
# Song 288: "2 Up (Bad Boy Remix)"
# Song 289: "Dinner Table"
# Song 290: "WTW V1"
# Song 291: "Seen It All"
# Song 292: "Up 2 Me Now V4"
# Song 293: "Goat Emoji"
# Song 294: "Lyfestyle (2020)"
# Song 295: "Hurricanë Katrina*"
# Song 296: "Rolled IN"
# Song 297: "Rëal lifë"
# Song 298: "​banKroLL*"
# Song 299: "Nëw friends*"
# Song 300: "Stupid Rich Shyt"
#
# Reached user-specified song limit (300).
# Done. Found 300 songs.

# %%
data = []
for song in songs_yeat:
    data.append(songs_yeat[song])

#remove the title of the song
for song in data:
    start_idx = song.find('\n')
    data[data.index(song)] = song[start_idx+1:]

# Removes words in brackets
import re
for song in data:
    data[data.index(song)] = re.sub(r'\[.*?\]', '', song)

# Removes words in parentheses
for song in data:
    data[data.index(song)] = re.sub(r'\(.*?\)', '', song)


# Sanity check
print(data[0][:295])
# Out:
# Yeat concert, Yeat, Yeat
# Man, one of the biggest artists in the world right now
# We seen it all, niggas was gettin' tazed
# Bitches was poppin' pussy by the front door
# Niggas was throwin' chairs, everything was goin' down
# Fifty-thousand people, Yeat concert, twizz shit right here
# Real twizz shit

# %%
# now we define our corpus
corpus = []
for i in range(len(data)):
    lines = data[i].split("\n")
    for line in lines:
        line = line.lower()
        line_words = [word for word in line.split(' ') if word.strip() != '']
        line_words.append(' \n ')
        corpus = corpus + line_words

# %%
# get the unique words in the corpus
unique_words = list(set(corpus))
vocab_size = len(unique_words)
words = {w: idx for idx, w in enumerate(unique_words)}
print('Vocab size:', vocab_size)
# Out:
# Vocab size: 8299

# %%
# Now lets define our model
from keras.preprocessing.sequence import pad_sequences
from keras.layers import Embedding, LSTM, Dense, Dropout,Bidirectional,GlobalMaxPool1D
from keras.callbacks import EarlyStopping
from keras.models import Sequential
import numpy as np

# %%
sequence_length = 10
step = 2
prev_words = []
next_words = []
sequence = []
for i in range(0, len(corpus) - sequence_length, step):
    prev_words.append(corpus[i: i + sequence_length ])
    next_words.append(corpus[i + sequence_length ])

# %%
word_index = {w: idx for idx, w in enumerate(unique_words)}
index_word = {idx: w for idx, w in enumerate(unique_words)}

# %%
def generator(prev_word_list, next_word_list, batch_size):
    index = 0
    while True:
        x = np.zeros((batch_size, sequence_length), dtype=np.int32)
        y = np.zeros((batch_size), dtype=np.int32)
        for i in range(batch_size):
            for t, w in enumerate(prev_word_list[index % len(prev_word_list)]):
                x[i, t] = word_index[w]
            y[i] = word_index[next_word_list[index % len(prev_word_list)]]
            index = index + 1
        yield x, y

# %% [markdown]
# # LSTM Model

# %%
model = Sequential(name='Yeatinator')
model.add(Embedding(input_dim=vocab_size, output_dim=124))
model.add(LSTM(128, return_sequences=True))
model.add(Dropout(0.2))
model.add(Bidirectional(LSTM(64, return_sequences=True)))
model.add(GlobalMaxPool1D())
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(vocab_size, activation='softmax'))
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# Model: "Yeatinator"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional (Bidirectional)   │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_max_pooling1d            │ ?                      │   0 (unbuilt) │
# │ (GlobalMaxPooling1D)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(prev_words, next_words, test_size=0.2, random_state=42)

# %%
BATCH_SIZE = 128
model.fit(generator(X_train, y_train, BATCH_SIZE),
                    steps_per_epoch=int(len(X_train)/BATCH_SIZE) + 1,
                    epochs=10,
                    validation_data=generator(X_test, y_test, BATCH_SIZE),
                    validation_steps=int(len(X_test)/BATCH_SIZE) + 1)

# %%
source = "i'm at the top, who can stop me"
source = source.split(' ')
n_token = 100
lyrics = source.copy()
input_text = source.copy()
temperature = 1
for i in range(n_token):
    encoded = []
    for word in input_text:
        encoded.append(word_index[word])
    encoded = np.array(encoded)
    encoded = encoded.reshape(1, len(encoded))
    y_pred = model.predict(encoded, verbose=0)
    y_pred = y_pred/np.sum(y_pred)
    y_pred = np.random.choice(range(vocab_size), size=1, p=y_pred[0])[0]
    input_text.append(index_word[y_pred])
    if len(input_text) > sequence_length:
        input_text = input_text[1:]
    lyrics.append(index_word[y_pred])

print(' '.join(lyrics))
# Out:
# i'm at the top, who can stop me
#   i been the curb and the part
#   i said two day, i ruin types a life embed
#   i might also like
#   i'm got on the lot
#   bitch, fuck of on a shit and he i lie, but 'em pull
#   what that not chanel, you
#
#
#   mix the sky, when you doing a x, this, y'all in god, another lot, if you pull up with me, everyone keep the tonka, , that's high
#   bitch, bitch, i'm money around like them back, uh
#   yeah, you love an , yeah, i wanna brashing

# %% [markdown]
# #### The model generates lyrics in the same style as yeat. We can clearly see the limits of training a Model for generation from scratch. Also the fact that in songs (especially yeat) we don't always use correct grammar it can be difficult to learn the relationships between words. Lets try another approach where we fine tune GPT-2 so it incroporates yeats style.
#
# ![Yeatinator Logo](./yeatnogrammar.jpg)

# %% [markdown]
# ## Fine Tune GPT-2 model

# %%
# Load model directly
from transformers import AutoTokenizer, AutoModelForCausalLM
from transformers import TextDataset, DataCollatorForLanguageModeling
from transformers import GPT2Tokenizer, GPT2LMHeadModel
from transformers import Trainer, TrainingArguments

tokenizer_yeat= AutoTokenizer.from_pretrained("gpt2")
model_yeat = AutoModelForCausalLM.from_pretrained("gpt2")


def load_dataset(file_path, tokenizer, block_size = 128):
    dataset = TextDataset(
    tokenizer = tokenizer,
    file_path = file_path,
    block_size = block_size,
    )
    return dataset

def load_data_collator(tokenizer, mlm = False):
    data_collator = DataCollatorForLanguageModeling(
    tokenizer=tokenizer,
    mlm=mlm,
    )
    return data_collator

def train(train_file_path,
      output_dir,
      overwrite_output_dir,
      per_device_train_batch_size,
      num_train_epochs,
      save_steps):


    tokenizer = tokenizer_yeat
    train_dataset = load_dataset(train_file_path, tokenizer)
    data_collator = load_data_collator(tokenizer)

    tokenizer.save_pretrained(output_dir)

    model = model_yeat
    model.save_pretrained(output_dir)

    training_args = TrainingArguments(
        output_dir=output_dir,
        overwrite_output_dir=overwrite_output_dir,
        per_device_train_batch_size=per_device_train_batch_size,
        num_train_epochs=num_train_epochs,
        do_train= True
   )
    trainer = Trainer(
          model=model,
          args=training_args,
          data_collator=data_collator,
          train_dataset=train_dataset,
    )

    trainer.train()
    trainer.save_model()
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]

# %%
train_file_path = "/lines_of_data.txt"
model_name = 'gpt2'
output_dir = '/content/result'
overwrite_output_dir = False
per_device_train_batch_size = 8
num_train_epochs = 10
save_steps = 500

# %%
train(
    train_file_path=train_file_path,
    output_dir=output_dir,
    overwrite_output_dir=overwrite_output_dir,
    per_device_train_batch_size=per_device_train_batch_size,
    num_train_epochs=num_train_epochs,
    save_steps=save_steps
)
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (344983 > 1024). Running this sequence through the model will result in indexing errors
#     <div>
#
#       <progress value='3370' max='3370' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [3370/3370 19:05, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>3.087900</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>2.690300</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>2.478400</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>2.344400</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>2.232400</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>2.161700</td>
#     </tr>
#   </tbody>
# </table><p>

# %%
from transformers import PreTrainedTokenizerFast, GPT2LMHeadModel, GPT2TokenizerFast, GPT2Tokenizer

# %%
def generate_text(sequence, max_length):
    model = model_yeat
    tokenizer = tokenizer_yeat

    ids = tokenizer.encode(f'{sequence}', return_tensors='pt')

    final_outputs = model.generate(
        ids.to('cuda'),
        do_sample=True,
        max_length=max_length,
        pad_token_id=model.config.eos_token_id,
        #top_k=50,
        #top_p=0.95,
    )

    # Decode the generated output
    generated_text = tokenizer.decode(final_outputs[0], skip_special_tokens=True)

    # Remove parentheses
    formatted_text = generated_text.replace('(', '').replace(')', '')

    formatted_text = formatted_text.replace(', ', ',\n').replace('. ', '.\n')

    # Split text by lines and filter out empty lines
    lines = formatted_text.splitlines()
    non_empty_lines = [line for line in lines if line.strip()]  # Filter out empty or whitespace-only lines

    # Join the non-empty lines back with new lines
    final_text = "\n".join(non_empty_lines)

    # Print the final formatted text without extra empty lines
    print(final_text)

# %%
generate_text('im at the top',100)
# Out:
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# im at the top',
# 'I got a whole lot of fuckin' money,
# I got a whole lot of fuckin' bullets',
# "I got a whole lot of fuckin' bullets,
# just sayin' out loud",
# 'I got all these racks,
# yeah,
# all they rackie',
# "Yeah,
# I got these bitches on me,
# it's way too much food",
# "I'm fuckin' my money up,
# bitch,
# I'm fuckin' my money down ",
# "I might be the
